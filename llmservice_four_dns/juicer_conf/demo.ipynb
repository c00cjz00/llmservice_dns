# %%
# !python tools/process_data.py --config configs/demo1.yaml
# Out:
# 2024-06-08 02:25:24.502 | INFO     | data_juicer:setup_mp:64 - Setting multiprocess start method to 'forkserver'.
# 2024-06-08 02:26:47 | INFO     | data_juicer.config.config:646 - Back up the input config file [/data-juicer/configs/demo1.yaml] into the work_dir [/data-juicer/output/demo1]
# 2024-06-08 02:26:47 | INFO     | data_juicer.config.config:668 - Configuration table:
# ╒════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                        │ values                                                                                       │
# ╞════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                     │ [Path_fr(configs/demo1.yaml, cwd=/data-juicer)]                                              │
# ...

# %%
# !cat output/demo1/demo-00-of-01.jsonl
# Out:
# {"text":"目 錄\n理事長序 p1\n「癲癇學和腦電圖學名詞中文標準譯法」召集人序 p2\n1.「癫痫学和脑电图学名词中文标准译法」协议(简体) p4\n2.「癲癇學和腦電圖學名詞中文標準譯法」協議(繁體) p5\n3.「癲癇學和腦電圖學名詞中文標準譯法」協議簽署 p6\n4.「癲癇學和腦電圖學名詞中文標準譯法」協議附件 (2011年版) p7\n(一) Seizure p8\n(二) Epileptic syndrome p13\n(三) EEG p16\n(四)其他 p22\n索引 (以英文字母排序) p37\n理事長序\n現代醫學以英文為主要溝通文字，英文醫學名詞之中文譯名往往\n因地而異、甚至因人而異。長期以來，癲癇學和腦電圖學的專有名詞\n在全球華語地區，也有各種不同的中文譯名，對癲癇病人照護與學術\n交流造成極大困擾，實有必要對癲癇學和腦電圖學提出一個大家共同\n接受的中文標準譯法。\n台灣癲癇學界的專家於1998年發起，與大陸癲癇學專家就腦電圖\n學名詞中文譯法進行研議。後經多次往來協商，同時徵詢港、澳、新、\n馬等學者專家的意見，終達成此協議文本的共識。並於2011年11月25\n日在廈門由台灣、中國、香港、澳門、馬來西亞、新加坡等代表聯合\n簽署「癲癇學和腦電圖學名詞中文標準譯法」協議，送交國際抗癲癇\n聯盟備存。\n此協議的簽訂是兩岸醫學界的創舉，具有劃時代的意義。也希望\n藉由此協議內容的宣導與推廣，對癲癇處置的發展有所助益。最後，\n誠摯地對所有參與制定此中文標準譯法之兩岸學者致上最高謝意，也\n期望後續文本之修訂與增補，能使本協議更臻完備。\n台灣癲癇醫學會 第11屆理事長\n吳禹利\n2013.4.11\n1\n「癲癇學和腦電圖學名詞中文標準譯法」召集人序\n全球華人超過 14 億，佔世界總人口的五分一。癲癇為神經科常見病\n症，全球華人罹患癲癇之人數超過千萬。以往，「癲癇學和腦電圖學名詞」\n之中譯，在兩岸及各華語地區因地而異，甚至因人而異，對病人之溝通、\n照護與學術交流造成極大的困擾。為了溝通及病歷記錄之方便，「癲癇學\n和腦電圖學名詞」需要中文標準譯法。\n第四屆「台灣癲癇醫學會」(Taiwan Epilepsy Society, TES)黃棣棟理\n事長率先於1998年11月8日在台北國際會議中心發起「癲癇專有名詞中
# ...

# %%
# !python tools/process_data.py --config configs/demo2.yaml
# Out:
# 2024-06-08 02:28:45.152 | INFO     | data_juicer:setup_mp:64 - Setting multiprocess start method to 'forkserver'.
# 2024-06-08 02:28:56 | INFO     | data_juicer.config.config:646 - Back up the input config file [/data-juicer/configs/demo2.yaml] into the work_dir [/data-juicer/output/demo2]
# 2024-06-08 02:28:56 | INFO     | data_juicer.config.config:668 - Configuration table:
# ╒════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                        │ values                                                                                       │
# ╞════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                     │ [Path_fr(configs/demo2.yaml, cwd=/data-juicer)]                                              │
# ...

# %%
# !python tools/process_data.py --config configs/demo3.yaml
# Out:
# 2024-06-08 02:31:20.268 | INFO     | data_juicer:setup_mp:64 - Setting multiprocess start method to 'forkserver'.
# 2024-06-08 02:31:32 | INFO     | data_juicer.config.config:646 - Back up the input config file [/data-juicer/configs/demo3.yaml] into the work_dir [/data-juicer/output/demo3]
# 2024-06-08 02:31:32 | INFO     | data_juicer.config.config:668 - Configuration table:
# ╒════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                        │ values                                                                                       │
# ╞════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                     │ [Path_fr(configs/demo3.yaml, cwd=/data-juicer)]                                              │
# ...
